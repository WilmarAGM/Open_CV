# %%
from PIL import Image
import pytesseract

# %%
image = Image.open("text.png")
image = image.convert('L')
display(image)
# Out:
# <PIL.Image.Image image mode=L size=940x328>

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
text = pytesseract.image_to_string(image)
# Lo transforma en una cadena de caracteres.

# %%
image_2 = Image.open('Gym.png').convert('L')
Im_3 = image_2.crop((50,130,600,400))
text_2 = pytesseract.image_to_string(Im_3)
print(text_2)
# Out:
# Home Studio - Functional Fitness
